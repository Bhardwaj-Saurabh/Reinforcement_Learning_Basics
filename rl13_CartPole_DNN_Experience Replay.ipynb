# %%
#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %% [markdown]
# Pacman Dependancies

# %%
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1

# %% [markdown]
# # Imports and Helper functions

# %%
import gym
import numpy as np
import random
import math
import matplotlib.pyplot as plt
from IPython import display as ipythondisplay

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import time

from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start()

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
env = gym.make('CartPole-v1')
env.reset()

prev_screen = env.render(mode='rgb_array')
plt.imshow(prev_screen)

# %%
# Set the seed for env, pytorch and random module
seed = 27
env.seed(seed)
torch.manual_seed(seed)
random.seed(seed)

# %%
state_space = env.observation_space.shape[0]
action_space = env.action_space.n

# %%
def calculate_egreedy(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
                math.exp(-1. * steps_done / egreedy_decay)
    return epsilon

# %%
# define hyperparameters
num_episode = 500
gamma = 0.99
learning_rate = 0.01

egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 500
hidden_layer = 64
print_every = 10
egreedy_total = []

replay_memory_size = 50000
batch_size = 32

# %%
class ExperienceReplay(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, state, action, new_state, reward, done):
        transition = (state, action, new_state, reward, done)
        
        if self.position >= len(self.memory):
            self.memory.append(transition)
        else:
            self.memory[self.position] = transition

        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return zip(*random.sample(self.memory, batch_size))

    def __len__(self):
        return len(self.memory)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear1 = nn.Linear(state_space, hidden_layer)
        self.linear2 = nn.Linear(hidden_layer, action_space)
    
    def forward(self, x):
        out = F.relu(self.linear1(x))
        out = self.linear2(out)
        return out

# %%
class QNet_Agent(object):
    def __init__(self):
        self.nn = NeuralNetwork().to(device)
        self.loss_func = nn.MSELoss()
        self.optimizer = optim.Adam(params = self.nn.parameters(), lr = learning_rate)

    def select_Action(self, state, epsilon):

        random_greedy = torch.rand(1)[0]

        if random_greedy > epsilon:
            with torch.no_grad():
                state = torch.Tensor(state).to(device)
                action_from_nn = self.nn(state)
                action = torch.max(action_from_nn, 0)[1]
                action = action.item()
        else:
            action = env.action_space.sample()

        return action

    def optimize(self):

        if len(memory) < batch_size:
            return 

        state, action, new_state, reward, done = memory.sample(batch_size)
        
        state = torch.Tensor(state).to(device)
        new_state = torch.Tensor(new_state).to(device)
        reward = torch.Tensor(reward).to(device)
        action = torch.LongTensor(action).to(device)
        done = torch.Tensor(done).to(device)

        new_state_values = self.nn(new_state).detach()
        max_new_state_values = torch.max(new_state_values, 1)[0]
        target_value = reward + ( 1 - done ) * gamma * max_new_state_values
  
        predicted_value = self.nn(state).gather(1, action.unsqueeze(1)).squeeze(1)
        
        loss = self.loss_func(predicted_value, target_value)
    
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
agent = QNet_Agent()
memory = ExperienceReplay(replay_memory_size)

# %%
steps_total = []
total_reward = []
frames_total = 0
score_to_solve = 195
solved_after = 0
solved = False
start_time = time.time()

for i_episode in range(num_episode):
    state = env.reset()
    step = 0
    #for step in range(100):
    while True:
        step += 1
        frames_total += 1
        epsilon = calculate_egreedy(frames_total)
        action = agent.select_Action(state, epsilon)
        new_state, reward, done, info = env.step(action)
        memory.push(state, action, new_state, reward, done)

        agent.optimize()

        state = new_state
        # screen = env.render(mode='rgb_array')
        # plt.imshow(screen)
        # ipythondisplay.clear_output(wait=True)
        # ipythondisplay.display(plt.gcf())
        if done:
            steps_total.append(step)
            
            mean_reward_100 = sum(steps_total[-100:])/100
            
            if (mean_reward_100 > score_to_solve and solved == False):
                print("SOLVED! After %i episodes " % i_episode)
                solved_after = i_episode
                solved = True
            
            if (i_episode % print_every == 0):
                print("\n*** Episode %i *** \
                      \nAv.reward: [last %i]: %.2f, [last 100]: %.2f, [all]: %.2f \
                      \nepsilon: %.2f, frames_total: %i" 
                  % (i_episode,
                    print_every,
                    sum(steps_total[-print_every:])/print_every,
                    mean_reward_100,
                    sum(steps_total)/len(steps_total),
                    epsilon,
                    frames_total
                          ))
                elapsed_time = time.time() - start_time
                print("Elapsed time: ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))

            break
# Out:
# *** Episode 0 ***
# Av.reward: [last 10]: 1.30, [last 100]: 0.13, [all]: 13.00
# epsilon: 0.88, frames_total: 13
# Elapsed time:  00:00:00
#
# *** Episode 10 ***
# Av.reward: [last 10]: 15.00, [last 100]: 1.63, [all]: 14.82
# epsilon: 0.66, frames_total: 163
# Elapsed time:  00:00:00
#
# *** Episode 20 ***
# Av.reward: [last 10]: 14.90, [last 100]: 3.12, [all]: 14.86
# epsilon: 0.49, frames_total: 312
# Elapsed time:  00:00:00
#
# *** Episode 30 ***
# Av.reward: [last 10]: 10.80, [last 100]: 4.20, [all]: 13.55
# epsilon: 0.40, frames_total: 420
# Elapsed time:  00:00:00
#
# *** Episode 40 ***
# Av.reward: [last 10]: 38.30, [last 100]: 8.03, [all]: 19.59
# epsilon: 0.20, frames_total: 803
# Elapsed time:  00:00:01
#
# *** Episode 50 ***
# Av.reward: [last 10]: 25.50, [last 100]: 10.58, [all]: 20.75
# epsilon: 0.13, frames_total: 1058
# Elapsed time:  00:00:01
#
# *** Episode 60 ***
# Av.reward: [last 10]: 44.90, [last 100]: 15.07, [all]: 24.70
# epsilon: 0.06, frames_total: 1507
# Elapsed time:  00:00:02
#
# *** Episode 70 ***
# Av.reward: [last 10]: 57.60, [last 100]: 20.83, [all]: 29.34
# epsilon: 0.03, frames_total: 2083
# Elapsed time:  00:00:03
#
# *** Episode 80 ***
# Av.reward: [last 10]: 47.10, [last 100]: 25.54, [all]: 31.53
# epsilon: 0.03, frames_total: 2554
# Elapsed time:  00:00:04
#
# *** Episode 90 ***
# Av.reward: [last 10]: 61.10, [last 100]: 31.65, [all]: 34.78
# epsilon: 0.02, frames_total: 3165
# Elapsed time:  00:00:05
#
# *** Episode 100 ***
# Av.reward: [last 10]: 73.70, [last 100]: 38.89, [all]: 38.63
# epsilon: 0.02, frames_total: 3902
# Elapsed time:  00:00:06
#
# *** Episode 110 ***
# Av.reward: [last 10]: 193.20, [last 100]: 56.71, [all]: 52.56
# epsilon: 0.02, frames_total: 5834
# Elapsed time:  00:00:10
#
# *** Episode 120 ***
# Av.reward: [last 10]: 211.30, [last 100]: 76.35, [all]: 65.68
# epsilon: 0.02, frames_total: 7947
# Elapsed time:  00:00:14
#
# *** Episode 130 ***
# Av.reward: [last 10]: 234.80, [last 100]: 98.75, [all]: 78.59
# epsilon: 0.02, frames_total: 10295
# Elapsed time:  00:00:18
#
# *** Episode 140 ***
# Av.reward: [last 10]: 229.30, [last 100]: 117.85, [all]: 89.28
# epsilon: 0.02, frames_total: 12588
# Elapsed time:  00:00:22
#
# *** Episode 150 ***
# Av.reward: [last 10]: 198.10, [last 100]: 135.11, [all]: 96.48
# epsilon: 0.02, frames_total: 14569
# Elapsed time:  00:00:25
#
# *** Episode 160 ***
# Av.reward: [last 10]: 236.00, [last 100]: 154.22, [all]: 105.15
# epsilon: 0.02, frames_total: 16929
# Elapsed time:  00:00:29
#
# *** Episode 170 ***
# Av.reward: [last 10]: 219.00, [last 100]: 170.36, [all]: 111.81
# epsilon: 0.02, frames_total: 19119
# Elapsed time:  00:00:34
#
# *** Episode 180 ***
# Av.reward: [last 10]: 233.70, [last 100]: 189.02, [all]: 118.54
# epsilon: 0.02, frames_total: 21456
# Elapsed time:  00:00:39
# SOLVED! After 184 episodes
#
# *** Episode 190 ***
# Av.reward: [last 10]: 263.90, [last 100]: 209.30, [all]: 126.15
# epsilon: 0.02, frames_total: 24095
# Elapsed time:  00:00:44
#
# *** Episode 200 ***
# Av.reward: [last 10]: 320.50, [last 100]: 233.98, [all]: 135.82
# epsilon: 0.02, frames_total: 27300
# Elapsed time:  00:00:50
#
# *** Episode 210 ***
# Av.reward: [last 10]: 335.40, [last 100]: 248.20, [all]: 145.28
# epsilon: 0.02, frames_total: 30654
# Elapsed time:  00:00:56
#
# *** Episode 220 ***
# Av.reward: [last 10]: 410.60, [last 100]: 268.13, [all]: 157.29
# epsilon: 0.02, frames_total: 34760
# Elapsed time:  00:01:03
#
# *** Episode 230 ***
# Av.reward: [last 10]: 363.00, [last 100]: 280.95, [all]: 166.19
# epsilon: 0.02, frames_total: 38390
# Elapsed time:  00:01:09
#
# *** Episode 240 ***
# Av.reward: [last 10]: 341.80, [last 100]: 292.20, [all]: 173.48
# epsilon: 0.02, frames_total: 41808
# Elapsed time:  00:01:15
#
# *** Episode 250 ***
# Av.reward: [last 10]: 390.40, [last 100]: 311.43, [all]: 182.12
# epsilon: 0.02, frames_total: 45712
# Elapsed time:  00:01:22
#
# *** Episode 260 ***
# Av.reward: [last 10]: 452.60, [last 100]: 333.09, [all]: 192.48
# epsilon: 0.02, frames_total: 50238
# Elapsed time:  00:01:30
#
# *** Episode 270 ***
# Av.reward: [last 10]: 470.10, [last 100]: 358.20, [all]: 202.73
# epsilon: 0.02, frames_total: 54939
# Elapsed time:  00:01:38
#
# *** Episode 280 ***
# Av.reward: [last 10]: 22.70, [last 100]: 337.10, [all]: 196.32
# epsilon: 0.02, frames_total: 55166
# Elapsed time:  00:01:39
#
# *** Episode 290 ***
# Av.reward: [last 10]: 11.70, [last 100]: 311.88, [all]: 189.98
# epsilon: 0.02, frames_total: 55283
# Elapsed time:  00:01:39
#
# *** Episode 300 ***
# Av.reward: [last 10]: 11.00, [last 100]: 280.93, [all]: 184.03
# epsilon: 0.02, frames_total: 55393
# Elapsed time:  00:01:39
#
# *** Episode 310 ***
# Av.reward: [last 10]: 10.00, [last 100]: 248.39, [all]: 178.43
# epsilon: 0.02, frames_total: 55493
# Elapsed time:  00:01:39
#
# *** Episode 320 ***
# Av.reward: [last 10]: 18.80, [last 100]: 209.21, [all]: 173.46
# epsilon: 0.02, frames_total: 55681
# Elapsed time:  00:01:39
#
# *** Episode 330 ***
# Av.reward: [last 10]: 10.80, [last 100]: 173.99, [all]: 168.55
# epsilon: 0.02, frames_total: 55789
# Elapsed time:  00:01:40
#
# *** Episode 340 ***
# Av.reward: [last 10]: 13.40, [last 100]: 141.15, [all]: 164.00
# epsilon: 0.02, frames_total: 55923
# Elapsed time:  00:01:40
#
# *** Episode 350 ***
# Av.reward: [last 10]: 10.80, [last 100]: 103.19, [all]: 159.63
# epsilon: 0.02, frames_total: 56031
# Elapsed time:  00:01:40
#
# *** Episode 360 ***
# Av.reward: [last 10]: 13.10, [last 100]: 59.24, [all]: 155.57
# epsilon: 0.02, frames_total: 56162
# Elapsed time:  00:01:40
#
# *** Episode 370 ***
# Av.reward: [last 10]: 17.40, [last 100]: 13.97, [all]: 151.85
# epsilon: 0.02, frames_total: 56336
# Elapsed time:  00:01:41
#
# *** Episode 380 ***
# Av.reward: [last 10]: 20.30, [last 100]: 13.73, [all]: 148.40
# epsilon: 0.02, frames_total: 56539
# Elapsed time:  00:01:41
#
# *** Episode 390 ***
# Av.reward: [last 10]: 28.50, [last 100]: 15.41, [all]: 145.33
# epsilon: 0.02, frames_total: 56824
# Elapsed time:  00:01:42
#
# *** Episode 400 ***
# Av.reward: [last 10]: 26.40, [last 100]: 16.95, [all]: 142.36
# epsilon: 0.02, frames_total: 57088
# Elapsed time:  00:01:42
#
# *** Episode 410 ***
# Av.reward: [last 10]: 38.70, [last 100]: 19.82, [all]: 139.84
# epsilon: 0.02, frames_total: 57475
# Elapsed time:  00:01:43
#
# *** Episode 420 ***
# Av.reward: [last 10]: 109.50, [last 100]: 28.89, [all]: 139.12
# epsilon: 0.02, frames_total: 58570
# Elapsed time:  00:01:45
#
# *** Episode 430 ***
# Av.reward: [last 10]: 367.00, [last 100]: 64.51, [all]: 144.41
# epsilon: 0.02, frames_total: 62240
# Elapsed time:  00:01:51
#
# *** Episode 440 ***
# Av.reward: [last 10]: 453.20, [last 100]: 108.49, [all]: 151.41
# epsilon: 0.02, frames_total: 66772
# Elapsed time:  00:01:59
#
# *** Episode 450 ***
# Av.reward: [last 10]: 477.10, [last 100]: 155.12, [all]: 158.63
# epsilon: 0.02, frames_total: 71543
# Elapsed time:  00:02:07
#
# *** Episode 460 ***
# Av.reward: [last 10]: 474.20, [last 100]: 201.23, [all]: 165.48
# epsilon: 0.02, frames_total: 76285
# Elapsed time:  00:02:15
#
# *** Episode 470 ***
# Av.reward: [last 10]: 500.00, [last 100]: 249.49, [all]: 172.58
# epsilon: 0.02, frames_total: 81285
# Elapsed time:  00:02:24
#
# *** Episode 480 ***
# Av.reward: [last 10]: 500.00, [last 100]: 297.46, [all]: 179.39
# epsilon: 0.02, frames_total: 86285
# Elapsed time:  00:02:33
#
# *** Episode 490 ***
# Av.reward: [last 10]: 500.00, [last 100]: 344.61, [all]: 185.92
# epsilon: 0.02, frames_total: 91285
# Elapsed time:  00:02:42

# %%
print("Average reward: %.2f" % (sum(steps_total)/num_episode))
print("Average reward (last 100 episodes): %.2f" % (sum(steps_total[-100:])/100))

if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# Average reward: 190.97
# Average reward (last 100 episodes): 384.16
# Solved after 184 episodes

# %%
# Plot graphs for rewards and steps
    
plt.figure(figsize=(12,5))
plt.title("Rewards")
plt.bar(torch.arange(len(steps_total)), steps_total, alpha=0.6, color='green', width=1)
plt.show()

# %%
env.close()
