# %%
#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %% [markdown]
# Pacman Dependancies

# %%
# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# !pip install gym[atari] > /dev/null 2>&1
# Out:
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (57.4.0)
# Collecting setuptools
#   Downloading setuptools-62.3.2-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.3 MB/s
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0+zzzcolab20220506162203 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed setuptools-62.3.2

# %% [markdown]
# # Imports and Helper functions

# %%
import gym
import numpy as np
import random
import math
import matplotlib.pyplot as plt
from IPython import display as ipythondisplay

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import time

from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start()

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
env = gym.make('CartPole-v1')
env.reset()

prev_screen = env.render(mode='rgb_array')
plt.imshow(prev_screen)

# %%
# Set the seed for env, pytorch and random module
seed = 27
env.seed(seed)
torch.manual_seed(seed)
random.seed(seed)

# %%
state_space = env.observation_space.shape[0]
action_space = env.action_space.n

# %%
def calculate_egreedy(steps_done):
    epsilon = egreedy_final + (egreedy - egreedy_final) * \
                math.exp(-1. * steps_done / egreedy_decay)
    return epsilon

# %%
# define hyperparameters
num_episode = 500
gamma = 0.99
learning_rate = 0.01

egreedy = 0.9
egreedy_final = 0.02
egreedy_decay = 500
hidden_layer = 64
print_every = 10
egreedy_total = []

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.linear1 = nn.Linear(state_space, hidden_layer)
        self.linear2 = nn.Linear(hidden_layer, action_space)
    
    def forward(self, x):
        out = F.relu(self.linear1(x))
        out = self.linear2(out)
        return out

# %%
class QNet_Agent(object):
    def __init__(self):
        self.nn = NeuralNetwork().to(device)
        self.loss_func = nn.MSELoss()
        self.optimizer = optim.Adam(params = self.nn.parameters(), lr = learning_rate)

    def select_Action(self, state, epsilon):

        random_greedy = torch.rand(1)[0]

        if random_greedy > epsilon:
            with torch.no_grad():
                state = torch.Tensor(state).to(device)
                action_from_nn = self.nn(state)
                action = torch.max(action_from_nn, 0)[1]
                action = action.item()
        else:
            action = env.action_space.sample()

        return action

    def optimize(self, state, action, new_state, reward, done):
        
        state = torch.Tensor(state).to(device)
        new_state = torch.Tensor(new_state).to(device)
        reward = torch.Tensor([reward]).to(device)
        if done:
            target_value = reward
        else:
            new_state_values = self.nn(new_state).detach()
            max_new_state_values = torch.max(new_state_values) 
            target_value = reward + gamma * max_new_state_values

        predicted_value = self.nn(state)[action]

        loss = self.loss_func(predicted_value, target_value)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
agent = QNet_Agent()

# %%
steps_total = []
total_reward = []
frames_total = 0
score_to_solve = 195
solved_after = 0
solved = False
start_time = time.time()

for i_episode in range(num_episode):
    state = env.reset()
    step = 0
    #for step in range(100):
    while True:
        step += 1
        frames_total += 1
        epsilon = calculate_egreedy(frames_total)
        action = agent.select_Action(state, epsilon)
        new_state, reward, done, info = env.step(action)

        agent.optimize(state, action, new_state, reward, done)

        state = new_state
        # screen = env.render(mode='rgb_array')
        # plt.imshow(screen)
        # ipythondisplay.clear_output(wait=True)
        # ipythondisplay.display(plt.gcf())
        if done:
            steps_total.append(step)
            
            mean_reward_100 = sum(steps_total[-100:])/100
            
            if (mean_reward_100 > score_to_solve and solved == False):
                print("SOLVED! After %i episodes " % i_episode)
                solved_after = i_episode
                solved = True
            
            if (i_episode % print_every == 0):
                
                
                
                print("\n*** Episode %i *** \
                      \nAv.reward: [last %i]: %.2f, [last 100]: %.2f, [all]: %.2f \
                      \nepsilon: %.2f, frames_total: %i" 
                  % 
                  ( i_episode,
                    print_every,
                    sum(steps_total[-print_every:])/print_every,
                    mean_reward_100,
                    sum(steps_total)/len(steps_total),
                    epsilon,
                    frames_total
                          ) 
                  )
                  
                elapsed_time = time.time() - start_time
                print("Elapsed time: ", time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))

            break
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:529: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# *** Episode 0 ***
# Av.reward: [last 10]: 2.10, [last 100]: 0.21, [all]: 21.00
# epsilon: 0.87, frames_total: 21
# Elapsed time:  00:00:00
#
# *** Episode 10 ***
# Av.reward: [last 10]: 40.40, [last 100]: 4.25, [all]: 38.64
# epsilon: 0.44, frames_total: 425
# Elapsed time:  00:00:00
#
# *** Episode 20 ***
# Av.reward: [last 10]: 39.50, [last 100]: 8.20, [all]: 39.05
# epsilon: 0.26, frames_total: 820
# Elapsed time:  00:00:01
#
# *** Episode 30 ***
# Av.reward: [last 10]: 91.50, [last 100]: 17.35, [all]: 55.97
# epsilon: 0.12, frames_total: 1735
# Elapsed time:  00:00:02
#
# *** Episode 40 ***
# Av.reward: [last 10]: 142.20, [last 100]: 31.57, [all]: 77.00
# epsilon: 0.10, frames_total: 3157
# Elapsed time:  00:00:05
#
# *** Episode 50 ***
# Av.reward: [last 10]: 66.80, [last 100]: 38.25, [all]: 75.00
# epsilon: 0.10, frames_total: 3825
# Elapsed time:  00:00:06
#
# *** Episode 60 ***
# Av.reward: [last 10]: 57.60, [last 100]: 44.01, [all]: 72.15
# epsilon: 0.10, frames_total: 4401
# Elapsed time:  00:00:07
#
# *** Episode 70 ***
# Av.reward: [last 10]: 49.40, [last 100]: 48.95, [all]: 68.94
# epsilon: 0.10, frames_total: 4895
# Elapsed time:  00:00:08
#
# *** Episode 80 ***
# Av.reward: [last 10]: 53.00, [last 100]: 54.25, [all]: 66.98
# epsilon: 0.10, frames_total: 5425
# Elapsed time:  00:00:08
#
# *** Episode 90 ***
# Av.reward: [last 10]: 180.20, [last 100]: 72.27, [all]: 79.42
# epsilon: 0.10, frames_total: 7227
# Elapsed time:  00:00:11
#
# *** Episode 100 ***
# Av.reward: [last 10]: 308.50, [last 100]: 102.91, [all]: 102.10
# epsilon: 0.10, frames_total: 10312
# Elapsed time:  00:00:17
#
# *** Episode 110 ***
# Av.reward: [last 10]: 339.50, [last 100]: 132.82, [all]: 123.49
# epsilon: 0.10, frames_total: 13707
# Elapsed time:  00:00:23
#
# *** Episode 120 ***
# Av.reward: [last 10]: 63.30, [last 100]: 135.20, [all]: 118.51
# epsilon: 0.10, frames_total: 14340
# Elapsed time:  00:00:24
#
# *** Episode 130 ***
# Av.reward: [last 10]: 92.80, [last 100]: 135.33, [all]: 116.55
# epsilon: 0.10, frames_total: 15268
# Elapsed time:  00:00:25
#
# *** Episode 140 ***
# Av.reward: [last 10]: 56.00, [last 100]: 126.71, [all]: 112.26
# epsilon: 0.10, frames_total: 15828
# Elapsed time:  00:00:26
#
# *** Episode 150 ***
# Av.reward: [last 10]: 98.40, [last 100]: 129.87, [all]: 111.34
# epsilon: 0.10, frames_total: 16812
# Elapsed time:  00:00:28
#
# *** Episode 160 ***
# Av.reward: [last 10]: 234.20, [last 100]: 147.53, [all]: 118.97
# epsilon: 0.10, frames_total: 19154
# Elapsed time:  00:00:32
#
# *** Episode 170 ***
# Av.reward: [last 10]: 334.50, [last 100]: 176.04, [all]: 131.57
# epsilon: 0.10, frames_total: 22499
# Elapsed time:  00:00:37
#
# *** Episode 180 ***
# Av.reward: [last 10]: 158.30, [last 100]: 186.57, [all]: 133.05
# epsilon: 0.10, frames_total: 24082
# Elapsed time:  00:00:40
# SOLVED! After 184 episodes
#
# *** Episode 190 ***
# Av.reward: [last 10]: 311.10, [last 100]: 199.66, [all]: 142.37
# epsilon: 0.10, frames_total: 27193
# Elapsed time:  00:00:45
#
# *** Episode 200 ***
# Av.reward: [last 10]: 237.60, [last 100]: 192.57, [all]: 147.11
# epsilon: 0.10, frames_total: 29569
# Elapsed time:  00:00:49
#
# *** Episode 210 ***
# Av.reward: [last 10]: 196.80, [last 100]: 178.30, [all]: 149.46
# epsilon: 0.10, frames_total: 31537
# Elapsed time:  00:00:52
#
# *** Episode 220 ***
# Av.reward: [last 10]: 210.30, [last 100]: 193.00, [all]: 152.22
# epsilon: 0.10, frames_total: 33640
# Elapsed time:  00:00:55
#
# *** Episode 230 ***
# Av.reward: [last 10]: 451.00, [last 100]: 228.82, [all]: 165.15
# epsilon: 0.10, frames_total: 38150
# Elapsed time:  00:01:03
#
# *** Episode 240 ***
# Av.reward: [last 10]: 454.90, [last 100]: 268.71, [all]: 177.17
# epsilon: 0.10, frames_total: 42699
# Elapsed time:  00:01:11
#
# *** Episode 250 ***
# Av.reward: [last 10]: 192.60, [last 100]: 278.13, [all]: 177.79
# epsilon: 0.10, frames_total: 44625
# Elapsed time:  00:01:15
#
# *** Episode 260 ***
# Av.reward: [last 10]: 362.60, [last 100]: 290.97, [all]: 184.87
# epsilon: 0.10, frames_total: 48251
# Elapsed time:  00:01:21
#
# *** Episode 270 ***
# Av.reward: [last 10]: 307.20, [last 100]: 288.24, [all]: 189.38
# epsilon: 0.10, frames_total: 51323
# Elapsed time:  00:01:26
#
# *** Episode 280 ***
# Av.reward: [last 10]: 190.90, [last 100]: 291.50, [all]: 189.44
# epsilon: 0.10, frames_total: 53232
# Elapsed time:  00:01:30
#
# *** Episode 290 ***
# Av.reward: [last 10]: 315.70, [last 100]: 291.96, [all]: 193.78
# epsilon: 0.10, frames_total: 56389
# Elapsed time:  00:01:35
#
# *** Episode 300 ***
# Av.reward: [last 10]: 73.80, [last 100]: 275.58, [all]: 189.79
# epsilon: 0.10, frames_total: 57127
# Elapsed time:  00:01:36
#
# *** Episode 310 ***
# Av.reward: [last 10]: 285.30, [last 100]: 284.43, [all]: 192.86
# epsilon: 0.10, frames_total: 59980
# Elapsed time:  00:01:41
#
# *** Episode 320 ***
# Av.reward: [last 10]: 142.30, [last 100]: 277.63, [all]: 191.29
# epsilon: 0.10, frames_total: 61403
# Elapsed time:  00:01:45
#
# *** Episode 330 ***
# Av.reward: [last 10]: 185.80, [last 100]: 251.11, [all]: 191.12
# epsilon: 0.10, frames_total: 63261
# Elapsed time:  00:01:48
#
# *** Episode 340 ***
# Av.reward: [last 10]: 248.60, [last 100]: 230.48, [all]: 192.81
# epsilon: 0.10, frames_total: 65747
# Elapsed time:  00:01:52
#
# *** Episode 350 ***
# Av.reward: [last 10]: 167.20, [last 100]: 227.94, [all]: 192.08
# epsilon: 0.10, frames_total: 67419
# Elapsed time:  00:01:54
#
# *** Episode 360 ***
# Av.reward: [last 10]: 149.00, [last 100]: 206.58, [all]: 190.88
# epsilon: 0.10, frames_total: 68909
# Elapsed time:  00:01:57
#
# *** Episode 370 ***
# Av.reward: [last 10]: 106.30, [last 100]: 186.49, [all]: 188.60
# epsilon: 0.10, frames_total: 69972
# Elapsed time:  00:01:59
#
# *** Episode 380 ***
# Av.reward: [last 10]: 135.70, [last 100]: 180.97, [all]: 187.22
# epsilon: 0.10, frames_total: 71329
# Elapsed time:  00:02:01
#
# *** Episode 390 ***
# Av.reward: [last 10]: 183.60, [last 100]: 167.76, [all]: 187.12
# epsilon: 0.10, frames_total: 73165
# Elapsed time:  00:02:04
#
# *** Episode 400 ***
# Av.reward: [last 10]: 321.10, [last 100]: 192.49, [all]: 190.46
# epsilon: 0.10, frames_total: 76376
# Elapsed time:  00:02:09
#
# *** Episode 410 ***
# Av.reward: [last 10]: 379.90, [last 100]: 201.95, [all]: 195.07
# epsilon: 0.10, frames_total: 80175
# Elapsed time:  00:02:15
#
# *** Episode 420 ***
# Av.reward: [last 10]: 451.10, [last 100]: 232.83, [all]: 201.15
# epsilon: 0.10, frames_total: 84686
# Elapsed time:  00:02:23
#
# *** Episode 430 ***
# Av.reward: [last 10]: 352.60, [last 100]: 249.51, [all]: 204.67
# epsilon: 0.10, frames_total: 88212
# Elapsed time:  00:02:28
#
# *** Episode 440 ***
# Av.reward: [last 10]: 248.40, [last 100]: 249.49, [all]: 205.66
# epsilon: 0.10, frames_total: 90696
# Elapsed time:  00:02:32
#
# *** Episode 450 ***
# Av.reward: [last 10]: 305.10, [last 100]: 263.28, [all]: 207.86
# epsilon: 0.10, frames_total: 93747
# Elapsed time:  00:02:37
#
# *** Episode 460 ***
# Av.reward: [last 10]: 338.50, [last 100]: 282.23, [all]: 210.70
# epsilon: 0.10, frames_total: 97132
# Elapsed time:  00:02:43
#
# *** Episode 470 ***
# Av.reward: [last 10]: 354.40, [last 100]: 307.04, [all]: 213.75
# epsilon: 0.10, frames_total: 100676
# Elapsed time:  00:02:49
#
# *** Episode 480 ***
# Av.reward: [last 10]: 309.10, [last 100]: 324.38, [all]: 215.73
# epsilon: 0.10, frames_total: 103767
# Elapsed time:  00:02:54
#
# *** Episode 490 ***
# Av.reward: [last 10]: 164.70, [last 100]: 322.49, [all]: 214.69
# epsilon: 0.10, frames_total: 105414
# Elapsed time:  00:02:57

# %%
print("Average reward: %.2f" % (sum(steps_total)/num_episode))
print("Average reward (last 100 episodes): %.2f" % (sum(steps_total[-100:])/100))

if solved:
    print("Solved after %i episodes" % solved_after)
# Out:
# Average reward: 213.02
# Average reward (last 100 episodes): 301.48
# Solved after 184 episodes

# %%
# Plot graphs for rewards and steps
    
plt.figure(figsize=(12,5))
plt.title("Rewards")
plt.bar(torch.arange(len(steps_total)), steps_total, alpha=0.6, color='green', width=1)
plt.show()

# %%
env.close()
